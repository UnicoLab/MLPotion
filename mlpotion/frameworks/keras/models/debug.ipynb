# %%
import keras
from inspection import KerasModelInspector

# %%
model = keras.Sequential()
model.add(keras.Input(shape=(250, 250, 3)))  # 250x250 RGB images
model.add(keras.layers.Conv2D(32, 5, strides=2, activation="relu"))
model.add(keras.layers.Conv2D(32, 3, activation="relu"))
model.add(keras.layers.MaxPooling2D(3))

# %%
mi = KerasModelInspector()
mi.inspect(model)
# Out:
# 2025-11-16 22:43:51.035 | INFO     | inspection:inspect:65 - Inspecting Keras model...
# 2025-11-16 22:43:51.035 | DEBUG    | inspection:_get_inputs:107 - Extracting model input specs...
# 2025-11-16 22:43:51.035 | DEBUG    | inspection:_get_outputs:128 - Extracting model output specs...
# 2025-11-16 22:43:51.036 | DEBUG    | inspection:_get_param_counts:149 - Computing model parameter counts...
# 2025-11-16 22:43:51.036 | DEBUG    | inspection:_get_signatures:183 - Extracting signatures (if any)...
# 2025-11-16 22:43:51.036 | DEBUG    | inspection:_get_layers_summary:222 - Extracting per-layer summary...
# 2025-11-16 22:43:51.036 | DEBUG    | inspection:inspect:87 - Keras model inspection result: {'name': 'sequential', 'backend': 'tensorflow', 'trainable': True, 'inputs': [{'index': 0, 'name': 'keras_tensor', 'shape': (None, 250, 250, 3), 'dtype': 'float32'}], 'input_names': ['keras_tensor'], 'outputs': [{'index': 0, 'name': 'keras_tensor_6', 'shape': (None, 40, 40, 32), 'dtype': 'float32'}], 'output_names': ['keras_tensor_6'], 'parameters': {'trainable': 11680, 'non_trainable': 0, 'total': 11680}, 'signatures': {}, 'layers': [{'name': 'conv2d', 'class_name': 'Conv2D', 'trainable': True}, {'name': 'conv2d_1', 'class_name': 'Conv2D', 'trainable': True}, {'name': 'max_pooling2d', 'class_name': 'MaxPooling2D', 'trainable': True}]}
# {'name': 'sequential',
#  'backend': 'tensorflow',
#  'trainable': True,
#  'inputs': [{'index': 0,
#    'name': 'keras_tensor',
#    'shape': (None, 250, 250, 3),
#    'dtype': 'float32'}],
#  'input_names': ['keras_tensor'],
#  'outputs': [{'index': 0,
#    'name': 'keras_tensor_6',
#    'shape': (None, 40, 40, 32),
#    'dtype': 'float32'}],
#  'output_names': ['keras_tensor_6'],
#  'parameters': {'trainable': 11680, 'non_trainable': 0, 'total': 11680},
#  'signatures': {},
#  'layers': [{'name': 'conv2d', 'class_name': 'Conv2D', 'trainable': True},
#   {'name': 'conv2d_1', 'class_name': 'Conv2D', 'trainable': True},
#   {'name': 'max_pooling2d', 'class_name': 'MaxPooling2D', 'trainable': True}]}
